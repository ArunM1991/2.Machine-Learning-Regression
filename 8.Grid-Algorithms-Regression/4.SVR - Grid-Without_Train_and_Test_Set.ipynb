# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent = dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['linear','rbf','poly','sigmoid'],'C':[10,100,500,1000,2000,3000,5000,10000]}
grid = GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\Genuine\Anaconda3\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 500, 1000, 2000, 3000, 5000, 10000],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)

from sklearn.metrics import r2_score
r_score = r2_score(dependent,grid_predictions)
print('The R_score value for best parameter {}:'.format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 1000, 'kernel': 'linear'}: 0.717904972094582

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.415703      0.022210         0.056616        0.011502      10
# 1        0.413701      0.031464         0.170044        0.028243      10
# 2        0.353685      0.016993         0.067019        0.000894      10
# 3        0.500322      0.007084         0.122433        0.000490      10
# 4        0.804399      0.045432         0.049814        0.016598     100
# 5        0.427305      0.010363         0.146239        0.014774     100
# 6        0.359288      0.005741         0.061617        0.004801     100
# 7        0.491321      0.005880         0.122633        0.000490     100
# 8        1.843262      0.095618         0.065218        0.002482     500
# 9        0.466515      0.042773         0.204054        0.050543     500
# 10       0.448906      0.025291         0.072619        0.010985     500
# 11       0.499323      0.006677         0.127232        0.006014     500
# 12       2.855519      0.101935         0.064217        0.000749    1000
# 13       0.442908      0.008161         0.206054        0.015867    1000
# 14       0.556937      0.049958         0.044613        0.016672    1000
# 15       0.497923      0.007306         0.125034        0.005515    1000
# 16       5.144296      0.829902         0.056816        0.013411    2000
# 17       0.463114      0.010528         0.188850        0.019634    2000
# 18       0.578943      0.019161         0.069620        0.004631    2000
# 19       0.487321      0.014828         0.126832        0.004356    2000
# 20       8.672790      2.100850         0.066217        0.008037    3000
# 21       0.456713      0.026211         0.157842        0.020060    3000
# 22       0.694972      0.055149         0.064418        0.000490    3000
# 23       0.516927      0.021845         0.128235        0.005777    3000
# 24      12.695205      1.245142         0.056817        0.013925    5000
# 25       0.498722      0.013635         0.152647        0.001023    5000
# 26       0.899426      0.089967         0.064416        0.000800    5000
# 27       0.520530      0.013898         0.124433        0.004318    5000
# 28      24.706351      6.356661         0.056416        0.014225   10000
# 29       0.523529      0.006801         0.155640        0.003139   10000
# 30       1.189297      0.050361         0.065418        0.001357   10000
# 31       0.502324      0.069575         0.108628        0.014627   10000
#
#    param_kernel                             params  split0_test_score  \
# 0        linear      {'C': 10, 'kernel': 'linear'}          -0.018943
# 1           rbf         {'C': 10, 'kernel': 'rbf'}          -0.110409
# 2          poly        {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid     {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4        linear     {'C': 100, 'kernel': 'linear'}           0.559313
# 5           rbf        {'C': 100, 'kernel': 'rbf'}          -0.160182
# 6          poly       {'C': 100, 'kernel': 'poly'}          -0.132885
# 7       sigmoid    {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 8        linear     {'C': 500, 'kernel': 'linear'}           0.632135
# 9           rbf        {'C': 500, 'kernel': 'rbf'}          -0.160916
# 10         poly       {'C': 500, 'kernel': 'poly'}          -0.111995
# 11      sigmoid    {'C': 500, 'kernel': 'sigmoid'}          -0.590878
# 12       linear    {'C': 1000, 'kernel': 'linear'}           0.736398
# 13          rbf       {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 14         poly      {'C': 1000, 'kernel': 'poly'}          -0.080527
# 15      sigmoid   {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 16       linear    {'C': 2000, 'kernel': 'linear'}           0.682349
# 17          rbf       {'C': 2000, 'kernel': 'rbf'}          -0.143510
# 18         poly      {'C': 2000, 'kernel': 'poly'}          -0.020567
# 19      sigmoid   {'C': 2000, 'kernel': 'sigmoid'}          -7.209317
# 20       linear    {'C': 3000, 'kernel': 'linear'}           0.677778
# 21          rbf       {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 22         poly      {'C': 3000, 'kernel': 'poly'}           0.037700
# 23      sigmoid   {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
# 24       linear    {'C': 5000, 'kernel': 'linear'}           0.675403
# 25          rbf       {'C': 5000, 'kernel': 'rbf'}          -0.101592
# 26         poly      {'C': 5000, 'kernel': 'poly'}           0.146604
# 27      sigmoid   {'C': 5000, 'kernel': 'sigmoid'}         -41.235764
# 28       linear   {'C': 10000, 'kernel': 'linear'}           0.671838
# 29          rbf      {'C': 10000, 'kernel': 'rbf'}          -0.034323
# 30         poly     {'C': 10000, 'kernel': 'poly'}           0.353741
# 31      sigmoid  {'C': 10000, 'kernel': 'sigmoid'}        -157.507980
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4            0.521798           0.547691           0.538805
# 5           -0.107253          -0.123430          -0.137753
# 6           -0.082461          -0.129220          -0.139962
# 7           -0.160831          -0.117544          -0.137984
# 8            0.587195           0.619095           0.610472
# 9           -0.103514          -0.128312          -0.139323
# 10          -0.061455          -0.105944          -0.118600
# 11          -0.759765          -0.609333          -0.619830
# 12           0.675162           0.680002           0.699377
# 13          -0.098267          -0.123724          -0.137137
# 14          -0.028469          -0.073376          -0.086611
# 15          -2.686121          -2.194563          -2.210858
# 16           0.630642           0.750714           0.646368
# 17          -0.087595          -0.113312          -0.128591
# 18           0.035685          -0.011468          -0.024587
# 19          -9.282940          -7.776578          -7.745074
# 20           0.626814           0.732806           0.633479
# 21          -0.075578          -0.100199          -0.116051
# 22           0.098496           0.049291           0.035615
# 23         -20.498908         -17.095474         -16.750877
# 24           0.622331           0.730635           0.632702
# 25          -0.050054          -0.071892          -0.090419
# 26           0.213077           0.162043           0.149387
# 27         -54.604842         -46.081742         -44.690976
# 28           0.618390           0.729404           0.630477
# 29           0.013981          -0.005817          -0.025434
# 30           0.405853           0.360495           0.362541
# 31        -212.288920        -178.166630        -172.476929
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672               11
# 1           -0.124428        -0.101276        0.016459               16
# 2           -0.179328        -0.125899        0.031794               20
# 3           -0.108716        -0.107639        0.012029               17
# 4            0.508518         0.535225        0.018122                7
# 5           -0.209551        -0.147634        0.035511               25
# 6           -0.189219        -0.134749        0.033948               22
# 7           -0.130402        -0.137843        0.014263               23
# 8            0.589494         0.607678        0.017242                6
# 9           -0.213145        -0.149042        0.037006               26
# 10          -0.164165        -0.112432        0.032727               18
# 11          -0.539246        -0.623810        0.073409               27
# 12           0.677952         0.693778        0.022955                1
# 13          -0.206405        -0.144193        0.036262               24
# 14          -0.134493        -0.080695        0.033795               14
# 15          -1.942521        -2.215441        0.255409               28
# 16           0.722261         0.686467        0.045056                2
# 17          -0.193992        -0.133400        0.035492               21
# 18          -0.076360        -0.019459        0.035693               12
# 19          -6.891719        -7.781126        0.821557               29
# 20           0.698692         0.673914        0.039876                3
# 21          -0.179304        -0.120018        0.034578               19
# 22          -0.020924         0.040035        0.038064               10
# 23         -15.012168       -16.983856        1.914783               30
# 24           0.694594         0.671133        0.039919                4
# 25          -0.150877        -0.092967        0.033824               15
# 26           0.083869         0.150996        0.041241                9
# 27         -40.003347       -45.323334        5.140660               31
# 28           0.691143         0.668251        0.040471                5
# 29          -0.081482        -0.026615        0.032099               13
# 30           0.288803         0.354287        0.037561                8
# 31        -154.800555      -175.048203       20.595309               32

# %%
age_input=int(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Somker Yes 0 or 1:"))
# Out:
# Age:33
# BMI:255.68
# Children:3
# Sex Male 0 or 1:1
# Somker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Future_Prediction = {}'.format(Future_Prediction))
# Out:
# Future_Prediction = [12219.62890474]
# C:\Users\Genuine\Anaconda3\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   "X does not have valid feature names, but"
