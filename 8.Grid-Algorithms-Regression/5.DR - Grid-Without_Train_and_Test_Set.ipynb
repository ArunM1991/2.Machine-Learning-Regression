# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent = dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['friedman_mse','squared_error','absolute_error','poisson'],
             'max_features':['auto','sqrt','log2'],
             'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'squared_error',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)

from sklearn.metrics import r2_score
r_score = r2_score(dependent,grid_predictions)
print('The R_score value for best parameter {}:'.format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}: 0.998667156135576

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.027204      0.018660         0.019203    2.240407e-02
# 1        0.025606      0.015515         0.008001    9.416779e-07
# 2        0.025602      0.012800         0.008001    1.293627e-06
# 3        0.035199      0.023520         0.012803    3.919114e-03
# 4        0.027206      0.014838         0.007999    1.274146e-06
# 5        0.017603      0.003202         0.009599    3.198409e-03
# 6        0.038401      0.015505         0.012801    6.400001e-03
# 7        0.016002      0.000002         0.009603    3.199530e-03
# 8        0.017604      0.003200         0.009600    3.200770e-03
# 9        0.020803      0.006401         0.008000    1.933397e-06
# 10       0.024004      0.008767         0.009601    3.199554e-03
# 11       0.032005      0.019599         0.009602    3.200412e-03
# 12       0.145616      0.015516         0.009603    3.199816e-03
# 13       0.086408      0.019857         0.044807    1.866254e-02
# 14       0.067209      0.011974         0.009603    3.199030e-03
# 15       0.078409      0.007840         0.025605    2.110708e-02
# 16       0.092806      0.038406         0.020807    2.182276e-02
# 17       0.081611      0.026489         0.009602    3.200817e-03
# 18       0.033603      0.009334         0.019207    1.567703e-02
# 19       0.025604      0.011759         0.011202    3.920924e-03
# 20       0.022405      0.003203         0.008002    1.237941e-06
# 21       0.022405      0.012800         0.009600    3.198481e-03
# 22       0.025604      0.011760         0.008005    5.969041e-06
# 23       0.019205      0.008159         0.011201    3.920087e-03
#
#    param_criterion param_max_features param_splitter  \
# 0     friedman_mse               auto           best
# 1     friedman_mse               auto         random
# 2     friedman_mse               sqrt           best
# 3     friedman_mse               sqrt         random
# 4     friedman_mse               log2           best
# 5     friedman_mse               log2         random
# 6    squared_error               auto           best
# 7    squared_error               auto         random
# 8    squared_error               sqrt           best
# 9    squared_error               sqrt         random
# 10   squared_error               log2           best
# 11   squared_error               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'max_features': ...           0.710794
# 1   {'criterion': 'friedman_mse', 'max_features': ...           0.732935
# 2   {'criterion': 'friedman_mse', 'max_features': ...           0.785088
# 3   {'criterion': 'friedman_mse', 'max_features': ...           0.765554
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.733079
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.674136
# 6   {'criterion': 'squared_error', 'max_features':...           0.713152
# 7   {'criterion': 'squared_error', 'max_features':...           0.701831
# 8   {'criterion': 'squared_error', 'max_features':...           0.746526
# 9   {'criterion': 'squared_error', 'max_features':...           0.636880
# 10  {'criterion': 'squared_error', 'max_features':...           0.752881
# 11  {'criterion': 'squared_error', 'max_features':...           0.656772
# 12  {'criterion': 'absolute_error', 'max_features'...           0.733777
# 13  {'criterion': 'absolute_error', 'max_features'...           0.696256
# 14  {'criterion': 'absolute_error', 'max_features'...           0.685140
# 15  {'criterion': 'absolute_error', 'max_features'...           0.717149
# 16  {'criterion': 'absolute_error', 'max_features'...           0.704935
# 17  {'criterion': 'absolute_error', 'max_features'...           0.764784
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.705300
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.547548
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.715798
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.723381
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.584685
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.599618
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.654041           0.723330           0.744186
# 1            0.600755           0.733449           0.646752
# 2            0.634132           0.760543           0.719772
# 3            0.595338           0.645968           0.684135
# 4            0.600312           0.554578           0.679914
# 5            0.543398           0.635809           0.691589
# 6            0.651164           0.718989           0.724557
# 7            0.623988           0.698753           0.776466
# 8            0.569825           0.683198           0.664555
# 9            0.464529           0.652803           0.735799
# 10           0.640913           0.741818           0.615963
# 11           0.630818           0.703421           0.686189
# 12           0.633288           0.713274           0.711550
# 13           0.653248           0.748741           0.721893
# 14           0.558631           0.729474           0.629058
# 15           0.576825           0.674861           0.710013
# 16           0.525502           0.583174           0.706301
# 17           0.595282           0.652097           0.741072
# 18           0.648843           0.699188           0.758761
# 19           0.522494           0.720013           0.643657
# 20           0.376643           0.615248           0.511141
# 21           0.541737           0.542486           0.588400
# 22           0.450680           0.619093           0.623207
# 23           0.564816           0.686700           0.646466
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.665348         0.699540        0.034424                5
# 1            0.749038         0.692586        0.058341                9
# 2            0.683412         0.716589        0.053915                1
# 3            0.668546         0.671908        0.055617               13
# 4            0.597737         0.633124        0.064310               18
# 5            0.673579         0.643702        0.053358               16
# 6            0.675977         0.696768        0.028448                8
# 7            0.738942         0.707996        0.050649                4
# 8            0.702265         0.673274        0.058451               12
# 9            0.556374         0.609277        0.092103               21
# 10           0.745644         0.699444        0.058618                6
# 11           0.649598         0.665360        0.026069               14
# 12           0.748950         0.708168        0.039909                3
# 13           0.745570         0.713142        0.035406                2
# 14           0.675631         0.655587        0.058032               15
# 15           0.689643         0.673698        0.050689               10
# 16           0.661646         0.636312        0.071207               17
# 17           0.614816         0.673610        0.067703               11
# 18           0.680877         0.698594        0.035929                7
# 19           0.674843         0.621711        0.075249               19
# 20           0.671342         0.578034        0.121740               23
# 21           0.631590         0.605519        0.067684               22
# 22           0.585232         0.572579        0.063076               24
# 23           0.555607         0.610642        0.049636               20

# %%
age_input=int(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Somker Yes 0 or 1:"))
# Out:
# Age:33
# BMI:255.68
# Children:3
# Sex Male 0 or 1:1
# Somker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Future_Prediction = {}'.format(Future_Prediction))
# Out:
# Future_Prediction = [4686.3887]
# C:\Users\Genuine\Anaconda3\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
